# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from skimage import color
from skimage import io
import scipy
from PIL import Image, ImageDraw

# %%
def readfile_as_dict(path):
    with open(path) as f:
        file = f.readlines()
    
    ans_list = [line.strip() for line in file]
    ans_dict = {}

    for line in ans_list:
        for i, char in enumerate(line):
            if char == ':':
                key = line[:i+1]
                value = [int(num) for num in line[i+2:].split() if num.isdigit()]
                ans_dict[key] = value
    return ans_dict

images = {}
for i in range(1, 5001):
    index = str(i).zfill(4)
    images[index] = Image.open('Images\\{}.jpg'.format(index))
    
ground_truth_dict = readfile_as_dict('examples\\example_result\\rank_groundtruth.txt')
ranklist_example_dict = readfile_as_dict('examples\\example_result\\rankList.txt')

print(ground_truth_dict)
print(ranklist_example_dict)
# Out:
# {'Q1:': [253, 656, 878, 895, 930, 1075, 1177, 1664, 1997, 2223, 2268, 2422, 2595, 2817, 2985, 3212, 3340, 3401, 3460, 4030, 4513, 4525, 4614, 4615, 4637], 'Q2:': [222, 266, 474, 641, 843, 1009, 1030, 1050, 1189, 1911, 2161, 2233, 2253, 2271, 2928, 3056, 3174, 3248, 3451, 3504, 3697, 3722, 4031, 4803, 4807], 'Q3:': [326, 342, 988, 1265, 1580, 1700, 2007, 2179, 2478, 2499, 2859, 2864, 2881, 3055, 3097, 3235, 3646, 3873, 3951, 4197, 4305, 4668, 4711, 4771, 4914], 'Q4:': [32, 227, 623, 889, 1078, 1126, 1156, 1253, 1484, 1494, 1617, 1645, 1783, 2418, 2612, 3002, 3082, 3165, 3463, 3558, 3775, 4242, 4604, 4952, 4957], 'Q5:': [77, 224, 285, 523, 650, 664, 841, 884, 917, 984, 1018, 1114, 1120, 1191, 1348, 1440, 1478, 1673, 1838, 1938, 2555, 3008, 3377, 3795, 3981], 'Q6:': [220, 221, 295, 350, 389, 608, 1035, 1195, 1442, 1954, 1983, 2062, 2104, 2159, 2224, 2235, 2251, 2757, 2902, 3261, 3471, 3782, 3894, 4593, 4720], 'Q7:': [581, 582, 944, 1029, 1139, 1266, 1516, 1559, 1775, 1786, 1905, 2119, 2266, 2468, 2591, 3266, 3294, 3448, 3586, 3596, 3713, 3842, 3872, 4459, 4798], 'Q8:': [241, 713, 726, 733, 767, 1199, 1207, 1513, 1738, 1763, 1971, 2185, 2556, 2593, 2876, 2891, 3224, 3423, 3506, 3661, 3727, 4290, 4588, 4785, 4835], 'Q9:': [62, 154, 325, 524, 614, 675, 759, 786, 932, 1233, 1570, 2069, 2259, 2341, 2437, 2939, 3196, 3271, 3398, 3651, 4218, 4263, 4566, 4905, 4974], 'Q10:': [49, 181, 185, 830, 1077, 1161, 1200, 2117, 2239, 2322, 2579, 2690, 2800, 2966, 3118, 3122, 3157, 3180, 3406, 3462, 4083, 4511, 4534, 4547, 4696]}
# {'Q1:': [253, 656, 878, 895, 930, 1075, 1177, 1664, 1997, 2223, 1948, 143, 254, 130, 2846, 3977, 3808, 1224, 750, 1507, 943, 120, 4132, 3998, 2056, 530, 4443, 3827, 563, 4938, 731, 4230, 4754, 378, 2218, 4569, 518, 2488, 3951, 2921, 2192, 2051, 1646, 3725, 4354, 159, 4173, 580, 48, 2743, 1185, 3884, 3102, 1376, 445, 626, 4824, 4078, 1351, 619, 4576, 1771, 1189, 223, 2847, 913, 4350, 1163, 2512, 3731, 326, 3420, 2278, 331, 1460, 2236, 1274, 2470, 4934, 3816, 338, 4623, 3174, 2874, 4073, 2810, 4785, 3845, 3909, 373, 3868, 4884, 1400, 3
, 91, 3405, 3470, 4080, 3465, 2727, 4473, 2052, 3982, 2513, 3851, 140, 166, 2403, 1017, 3716, 2016, 4891, 3444, 1724, 346, 3544, 3219, 918, 3391, 1466, 1434, 594, 3029, 1405, 4724, 520, 4210, 3123, 272, 4618, 2207, 4121, 236, 2837, 4175, 493, 2261, 4252, 4468, 4577, 3382, 3953, 250, 4662, 1503, 1898, 4024, 508, 2424, 2003, 3661, 3770, 1442, 2167, 1328, 3430, 2564, 4289, 79, 2404, 2682, 4867, 1527, 268, 2528, 4104, 148, 3490, 1338, 3572, 2788, 2360, 773, 658, 3443, 2758, 4506, 4887, 3355, 3633, 4306, 1504, 3335, 876, 4250, 2724, 4255, 1565, 4421, 824, 3258, 738, 2615, 4212, 1033, 4763, 2717, 3958, 2156, 627, 524, 3702, 87, 2902, 299, 1780, 888, 3663, 1475, 341, 2195, 4125, 4820, 2554, 266, 2775, 2818, 1749, 722, 4259, 2007, 809, 2466, 138, 561, 692, 229, 2448, 4901, 3543, 4392, 3213, 3744, 4841, 1795, 646, 2865, 27 ...

# %%
print(images['0002'])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=413x550 at 0x231CAF42FA0>

# %%
plt.imshow(np.mean(images['0007'], -1))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-91cf9de5da7a> in <module>
# ----> 1 plt.imshow(images['0007'][:, :, 0])
#
# TypeError: 'JpegImageFile' object is not subscriptable

# %%
from PIL import Image
plt.imshow(Image.fromarray(images['0007']).convert('L'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f863b868e0fa> in <module>
#       1 from PIL import Image
# ----> 2 plt.imshow(Image.fromarray(images['0007']).convert('L'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2770             obj = obj.tostring()
#    2771
# -> 2772     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2773
#    2774
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2710             return im
#    2711
# -> 2712     return frombytes(mode, size, data, decoder_name, args)
#    2713
#    2714
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2656
#    2657     im = new(mode, size)
# -> 2658     im.frombytes(data, decoder_name, args)
#    2659     return im
#    2660
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in frombytes(self, data, decoder_name, *args)
#     792         d = _getdecoder(self.mode, decoder_name, args)
#     793         d.setimage(self.im)
# --> 794         s = d.decode(data)
#     795
#     796         if s[0] >= 0:
#
# TypeError: a bytes-like object is required, not 'JpegImageFile'

# %%
pil_rgb2gray = lambda image_rgb: Image.fromarray(image_rgb).convert('L')

plt.imshow(pil_rgb2gray(images['1000']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0f9da48306e7> in <module>
#       1 pil_rgb2gray = lambda image_rgb: Image.fromarray(image_rgb).convert('L')
#       2
# ----> 3 plt.imshow(pil_rgb2gray(images['1000']))
#
# <ipython-input-10-0f9da48306e7> in <lambda>(image_rgb)
# ----> 1 pil_rgb2gray = lambda image_rgb: Image.fromarray(image_rgb).convert('L')
#       2
#       3 plt.imshow(pil_rgb2gray(images['1000']))
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2770             obj = obj.tostring()
#    2771
# -> 2772     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2773
#    2774
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2710             return im
#    2711
# -> 2712     return frombytes(mode, size, data, decoder_name, args)
#    2713
#    2714
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2656
#    2657     im = new(mode, size)
# -> 2658     im.frombytes(data, decoder_name, args)
#    2659     return im
#    2660
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in frombytes(self, data, decoder_name, *args)
#     792         d = _getdecoder(self.mode, decoder_name, args)
#     793         d.setimage(self.im)
# --> 794         s = d.decode(data)
#     795
#     796         if s[0] >= 0:
#
# TypeError: a bytes-like object is required, not 'JpegImageFile'
