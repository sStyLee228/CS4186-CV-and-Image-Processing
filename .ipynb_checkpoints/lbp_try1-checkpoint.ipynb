# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from skimage import color
from skimage import io
import scipy
from PIL import Image, ImageDraw

# %%
images = {}
for i in range(1, 5001):
    index = str(i).zfill(4)
    images[index] = Image.open('Images\\{}.jpg'.format(index))

# %%
print(images['0002'][0])
# Out:
# [[131 107  71]
#  [ 99  75  39]
#  [121  97  61]
#  ...
#  [167 163 160]
#  [163 159 156]
#  [154 150 147]]

# %%
plt.imshow(np.mean(images['0007'], -1))

# %%
plt.imshow(images['0007'][:, :, 0])

# %%
rgb_to_gray = lambda rgb: np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

plt.imshow(rgb_to_gray(images['0007']))

# %%
plt.imshow(color.rgb2gray(images['0007']))

# %%
from PIL import Image
plt.imshow(Image.fromarray(images['0007']).convert('L'))

# %%
pil_rgb2gray = lambda rgb: Image.fromarray(images['0007']).convert('L')

print(pil_rgb2gray(images['1000']).size)
# Out:
# (1000, 750)
